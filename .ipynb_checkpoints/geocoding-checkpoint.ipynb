# %%
# !pip install fuzzywuzzy python-Levenshtein
# Out:
# ...
#
#    ---------------------------------------- 0/3 [fuzzywuzzy]
#    ------------- -------------------------- 1/3 [Levenshtein]
#    ------------- -------------------------- 1/3 [Levenshtein]
#    ------------- -------------------------- 1/3 [Levenshtein]
#    ---------------------------------------- 3/3 [python-Levenshtein]
#
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\amras\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\amras\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\amras\anaconda3\Lib\site-packages)

# %%
import pandas as pd
import numpy as np
import re
import math
from pathlib import Path
from collections import defaultdict
from tqdm import tqdm
from fuzzywuzzy import fuzz, process
from rapidfuzz import process, fuzz
from geopy.distance import geodesic
from geopy.geocoders import Nominatim
import time
from sklearn.neighbors import BallTree
from math import atan2, degrees, radians, sin, cos
from rapidfuzz.fuzz import ratio

# %%
# Load data
DATA_DIR = Path("data")
RAW_DIR = DATA_DIR / "raw"
OUTPUT_DIR = Path("output")
GTFS_DIR = RAW_DIR / "ttc_gtfs"

unique_df = pd.read_csv(OUTPUT_DIR / "unique_locations_with_ids.csv")
ml_df = pd.read_csv(OUTPUT_DIR / "ml_dataset_ready.csv")
stops_df = pd.read_csv(GTFS_DIR / "stops.txt")
routes_df = pd.read_csv(GTFS_DIR / "routes.txt")
trips_df = pd.read_csv(GTFS_DIR / "trips.txt")
stop_times_df = pd.read_csv(GTFS_DIR / "stop_times.txt")
shapes_df = pd.read_csv(GTFS_DIR / "shapes.txt")
route_location_lookup = pd.read_csv(OUTPUT_DIR / "route_location_lookup.csv")
# Out:
# C:\Users\amras\AppData\Local\Temp\ipykernel_29564\2923102788.py:11: DtypeWarning: Columns (0: trip_id, 1: trip_short_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   trips_df = pd.read_csv(GTFS_DIR / "trips.txt")
# C:\Users\amras\AppData\Local\Temp\ipykernel_29564\2923102788.py:12: DtypeWarning: Columns (0: trip_id, 1: stop_headsign) have mixed types. Specify dtype option on import or set low_memory=False.
#   stop_times_df = pd.read_csv(GTFS_DIR / "stop_times.txt")

# %%
# Start from clean location IDs
location_base = unique_df.copy()

routes_per_location = (
    route_location_lookup
    .groupby("location_id")["route"]
    .apply(lambda x: list(set(x.astype(str))))
    .to_dict()
)

route_shape_ids = (
    trips_df
    .groupby("route_id")["shape_id"]
    .unique()
    .to_dict()
)


shape_points = (
    shapes_df
    .sort_values(["shape_id","shape_pt_sequence"])
    .groupby("shape_id")
    [["shape_pt_lat","shape_pt_lon"]]
    .apply(
        lambda x: list(
            zip(
                x.shape_pt_lat,
                x.shape_pt_lon
            )
        )
    )
    .to_dict()
)


route_shapes = {}

for route, shape_ids in route_shape_ids.items():

    pts = []

    for sid in shape_ids:
        pts.extend(
            shape_points.get(sid, [])
        )

    route_shapes[str(route)] = pts

route_trees = {}

for route, pts in route_shapes.items():

    if len(pts) == 0:
        continue

    arr = np.radians(
        np.array(pts)
    )

    route_trees[str(route)] = BallTree(
        arr,
        metric="haversine"
    )


route_stop_lookup = (
    stop_times_df
    .merge(
        trips_df[["trip_id","route_id"]],
        on="trip_id",
        how="left"
    )
    [["route_id","stop_id"]]
    .drop_duplicates()
)


route_stop_coords = (
    route_stop_lookup
    .merge(
        stops_df[
            [
                "stop_id",
                "stop_name",
                "stop_lat",
                "stop_lon"
            ]
        ],
        on="stop_id",
        how="left"
    )
)


route_stop_coords["route_id"] = (
    route_stop_coords["route_id"]
    .astype(str)
    .str.replace(".0", "", regex=False)
    .str.strip()
)

route_stop_coords = route_stop_coords.drop_duplicates(
    subset=["route_id", "stop_id"]
)

def route_distance(route_ids, lat, lon):

    point = np.radians([[lat, lon]])

    best = None

    for r in route_ids:

        tree = route_trees.get(str(r))

        if tree is None:
            continue


        dist, _ = tree.query(
            point,
            k=1
        )

        meters = (
            dist[0][0]
            *
            6371000
        )


        if best is None or meters < best:
            best = meters

    return best

# %%
def clean_street(text):
    text = text.upper()
    # remove station/platform/bus stop words
    remove_words = [
        "STATION",
        "SUBWAY",
        "PLATFORM",
        "BUS STOP"
    ]

    for w in remove_words:
        text = text.replace(w, " ")

    # normalize separators
    text = re.sub(r'\bAND\b|&|@|/|\bAT\b', '|', text)
    # remove street suffixes ONLY as separate words
    text = re.sub(r'\b(STREET|ST|AVENUE|AVE|ROAD|RD|BOULEVARD|BLVD)\b', '', text)
    # clean spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def normalize_input_street(x):
    x = x.upper()
    # remove location words
    x = re.sub(r'\b(STATION|SUBWAY|PLATFORM|STOP)\b', '', x)
    x = re.sub(r'\b(NORTH|SOUTH|EAST|WEST|N|S|E|W)\b', '', x)
    x = re.sub(r'\s+', ' ', x).strip()
    return x

def extract_streets(text):
    text = str(text).upper()
    text = re.sub(r'\bAND\b|&|@|/|\bAT\b', '|', text)
    parts = [
        x.strip()
        for x in text.split("|")
        if len(x.strip()) > 2
    ]
    parts = [
        normalize_input_street(x)
        for x in parts
    ]

    return parts[:2]

# %%
REMOVE_WORDS = [
    "STATION",
    "SUBWAY",
    "PLATFORM",
    "BUS BAY",
    "FARE GATE",
    "FARE_GATE",
    "ENTRANCE",
    "EXIT",
    "STAIRS",
    "ELEVATOR"
]

STREET_SUFFIX = [
    "ST",
    "ST.",
    "STREET",
    "AVE",
    "AV",
    "AVENUE",
    "RD",
    "ROAD",
    "DR",
    "DRIVE",
    "CRES",
    "CRESCENT",
    "BLVD",
    "BOULEVARD"
]


def cut_after_suffix(text):

    words = text.split()

    for i, word in enumerate(words):

        if word in STREET_SUFFIX:

            # keep street name + suffix location
            return " ".join(words[:i])

    return text

def clean_gtfs_tokens(text):

    text = str(text).upper()

    # REMOVE LANDMARKS AFTER DASH
    text = text.split("-")[0]

    # REMOVE BRACKETS
    text = re.sub(
        r'\(.*?\)',
        '',
        text
    )

    # split intersection
    parts = re.split(
        r'\bAT\b|@|&|AND|/',
        text
    )

    cleaned = []

    for p in parts:

        p = re.sub(
            r'\b(NORTH|SOUTH|EAST|WEST|N|S|E|W)\b',
            '',
            p
        )

        p = cut_after_suffix(p)

        p = re.sub(
            r'\s+',
            ' ',
            p
        ).strip()

        if len(p) > 2:
            cleaned.append(p)

    return cleaned[:2]

stops_df["street_tokens_clean"] = (stops_df["stop_name"].apply(clean_gtfs_tokens))
gtfs_match = stops_df[stops_df["street_tokens_clean"].apply(len) == 2].copy()
street_index = defaultdict(set)

for idx, row in gtfs_match.iterrows():
    for street in row["street_tokens_clean"]:
        street_index[street].add(idx)

def find_street_candidates(location):
    streets = extract_streets(location)
    result = get_street_candidates_with_recovery(streets)
    return {
        "streets_original": streets,
        "streets_used": result["streets_used"],
        "recovered": result["recovered"],
        "candidate_count": len(result["candidates"]),
        "candidates": result["candidates"]
    }

def location_type(location):

    x = location.upper()

    if "STATION" in x:
        return "STATION"

    if "LOOP" in x:
        return "LOOP"

    if "GARAGE" in x:
        return "GARAGE"

    if "AND" in x or "&" in x:
        return "INTERSECTION"

    return "OTHER"

# %%
street_vocab = set()
REMOVE_STREET_WORDS = {
    "SIDE",
    "STATION",
    "LOOP",
    "PLATFORM",
    "ENTRANCE",
    "EXIT"
}

def clean_vocab_word(x):
    words = x.split()
    words = [
        w for w in words
        if w not in REMOVE_STREET_WORDS
    ]
    return " ".join(words)

street_vocab = set()

for street in street_index.keys():
    clean = clean_vocab_word(street)
    if len(clean) > 2:
        street_vocab.add(clean)

street_vocab = list(street_vocab)


def recover_street_name(
    street,
    score_threshold=85
):

    results = process.extract(
        street,
        street_vocab,
        scorer=fuzz.WRatio,
        limit=5
    )

    # no candidates
    if not results:
        return street, 0

    # take best match
    match, score, index = results[0]

    if score >= score_threshold:
        return match, score

    return street, score

def get_street_candidates_with_recovery(streets):

    # Step 1: exact match
    candidates = get_street_candidates(streets)

    if len(candidates) > 0:
        return {
            "streets_used": streets,
            "recovered": False,
            "candidates": candidates
        }


    # Step 2: recover streets
    recovered = []

    for street in streets:
        new_street, score = recover_street_name(street)
        recovered.append(new_street)

    # Step 3: retry
    candidates = get_street_candidates(recovered)
    return {
        "streets_used": recovered,
        "recovered": True,
        "candidates": candidates
    }

stops_df["street_tokens_clean"] = (
    stops_df["stop_name"]
    .apply(clean_gtfs_tokens)
)


gtfs_match = stops_df[
    stops_df["street_tokens_clean"].apply(len) == 2
].copy()


street_index = defaultdict(set)

for idx, row in gtfs_match.iterrows():

    for street in row["street_tokens_clean"]:
        street_index[street].add(idx)

street_vocab = set()

for street in street_index.keys():
    clean = clean_vocab_word(street)

    if len(clean) > 2:
        street_vocab.add(clean)

street_vocab = list(street_vocab)

def get_street_candidates(streets):

    if len(streets) != 2:
        return []

    street1, street2 = streets

    # check if streets exist
    if street1 not in street_index:
        return []

    if street2 not in street_index:
        return []


    stops1 = street_index[street1]
    stops2 = street_index[street2]


    # intersection of stop IDs
    matched_ids = stops1.intersection(stops2)


    return list(matched_ids)

def score_candidate(row, requested_streets):

    score = 0

    tokens = set(row["street_tokens_clean"])

    requested = set(requested_streets)


    # 1. Street overlap
    if tokens == requested:
        score += 50


    # 2. Prefer normal stops
    name = row["stop_name"].upper()

    if "LOOP" in name:
        score -= 10

    if "WEST SIDE" in name:
        score -= 5


    # 3. Prefer standard "at" intersections
    if " AT " in name:
        score += 10


    return score

stops_df.loc[
    [540,3182],
    [
        "stop_id",
        "stop_name"
    ]
]

# trip_id -> route_id mapping
# Selected routes from your project (50 TTC routes)
selected_routes = set(
    route_location_lookup["route"]
    .astype(str)
    .unique()
)



# Trip -> route mapping
trip_route_df = trips_df[
    ["trip_id", "route_id"]
].copy()

trip_route_df["route_id"] = (
    trip_route_df["route_id"]
    .astype(str)
)


# Stop -> route mapping
stop_route_df = stop_times_df[
    [
        "trip_id",
        "stop_id"
    ]
].merge(
    trip_route_df,
    on="trip_id",
    how="left"
)

# KEEP ONLY YOUR SELECTED 50 ROUTES
stop_route_df = stop_route_df[
    stop_route_df["route_id"].isin(selected_routes)
]

# Build stop -> routes dictionary
stop_routes = (
    stop_route_df
    .groupby("stop_id")["route_id"]
    .apply(set)
    .to_dict()
)

print(
    "Stops with selected routes:",
    len(stop_routes)
)
# Out:
# Stops with selected routes: 4411

# %%
direction_cols = [
    "dir_N",
    "dir_S",
    "dir_E",
    "dir_W",
    "dir_UNKNOWN"
]

def decode_direction(row):
    for c in direction_cols:
        if row[c] == 1:
            return c.replace("dir_", "")
    return "UNKNOWN"


ml_df["direction"] = ml_df.apply(
    decode_direction,
    axis=1
)

ml_df["route"] = ml_df["route"].astype(str)

# Main direction lookup
direction_history = (
    ml_df
    .groupby(["location_id","route"])["direction"]
    .value_counts()
    .rename("count")
    .reset_index()
)

direction_lookup = (
    direction_history
    .groupby(["location_id","route"])
    .apply(
        lambda x: dict(
            zip(
                x["direction"],
                x["count"]
            )
        ),
        include_groups=False
    )
    .to_dict()
)

direction_summary = (
    ml_df
    .groupby(["location_id", "route"])["direction"]
    .agg(
        total="count",
        dominant_direction=lambda x: x.mode().iat[0],
        dominant_count=lambda x: x.value_counts().iloc[0]
    )
)

direction_summary["confidence"] = (
    direction_summary["dominant_count"] /
    direction_summary["total"]
)

stop_usage = (
    stop_times_df["stop_id"]
    .value_counts()
    .to_dict()
)

# %%
# normalization function
COMMON_FIXES = {
    # Original fixes
    "THORNCLIFF": "THORNCLIFFE",
    "LOCKPO": "LOCKPORT",
    "L AMORE": "LAMORE",
    "ST MATTHEW": "ST MATTHEWS",
    "TRITION": "TRITON",
    "BOROUGHQ": "BOROUGH",
    "BOROUG": "BOROUGH",
    "BOUROUGH": "BOROUGH",
    "KNIFGHTSB": "KNIGHTSBRIDGE",
    "KNIGHTSBR": "KNIGHTSBRIDGE",
    "EDLIOU": "EDILOU",
    "HRONER": "HORNER",
    "MCNICOL": "MCNICOLL",
    "NAIRIN": "NAIRN",
    "ABOT": "ABBOT",
    "ABBEY": "ABBEY",
    
    # New fixes - complete words/phrases only
    "THORNECLIF": "THORNCLIFFE",
    "THORNECLIFFE": "THORNCLIFFE",
    "THORNCLIF": "THORNCLIFFE",
    "THORNCLIIF": "THORNCLIFFE",
    "THRONCLIFF": "THORNCLIFFE",
    "THRONCLIFFE": "THORNCLIFFE",
    "THOTNCLIFF": "THORNCLIFFE",
    "THORNCILFFE": "THORNCLIFFE",
    "THORCLIFF": "THORNCLIFFE",
    "THORNCIFFE": "THORNCLIFFE",
    "THORNCLIFE": "THORNCLIFFE",
    "THORNCILFF": "THORNCLIFFE",
    "THRONECLIF": "THORNCLIFFE",
    "THORNCLLIFFE": "THORNCLIFFE",
    
    "MARTIN GROV": "MARTIN GROVE",
    "MARTIN GR": "MARTIN GROVE",
    "MARTIN GRO": "MARTIN GROVE",
    "MARTIN GROV": "MARTIN GROVE",
    "MRTIN GROVE": "MARTIN GROVE",
    "MARTING GROVE": "MARTIN GROVE",
    "MARTIN GROOVE": "MARTIN GROVE",
    
    "LAWRENCE STATION W": "LAWRENCE",
    "LAWRENCE STATION E": "LAWRENCE",
    "LAWRENCE STATION": "LAWRENCE",
    
    "ST CLAIR STATION W": "ST CLAIR",
    "ST CLAIR STATION": "ST CLAIR",
    
    "BLOO AND": "BLOOR AND",
    "DANF AND": "DANFORTH AND",
    "DANFORTH AV": "DANFORTH",
    
    "EGLINTON W": "EGLINTON",
    "EGLINTON E": "EGLINTON",
    "EGLINTON W STATION": "EGLINTON",
    
    "FINCH W": "FINCH",
    "FINCH E": "FINCH",
    "FINCH STATION W": "FINCH",
    "FINCH STATION E": "FINCH",
    "FINCH STATION": "FINCH",
    
    "KENNEDY STATION AND": "KENNEDY AND",
    "KENNEDY STATION": "KENNEDY",
    
    "ISLINGTON STATION AND": "ISLINGTON AND",
    "ISLINGTON STATION": "ISLINGTON",
    
    "DUFFERIN STATION AND": "DUFFERIN AND",
    "DUFFERIN STATION": "DUFFERIN",
    
    "BATHURST STATION AND": "BATHURST AND",
    "BATHURST STATION": "BATHURST",
    
    "WILSON STATION AND": "WILSON AND",
    "WILSON STATION": "WILSON",
    
    "QUEEN STATION AND": "QUEEN AND",
    "QUEEN STATION": "QUEEN",
    
    "KING STATION AND": "KING AND",
    "KING STATION": "KING",
    
    "PIONNER VILLAGE": "PIONEER VILLAGE",
    "PIONNEER VILLAGE": "PIONEER VILLAGE",
    "PIONVEER VILLAGE": "PIONEER VILLAGE",
    "PIOEER VILLAGE": "PIONEER VILLAGE",
    "PIONIER VILLAGE": "PIONEER VILLAGE",
    "PIOPNEER VILLAGE": "PIONEER VILLAGE",
    "PIONER VILLAGE": "PIONEER VILLAGE",
    
    "SCARBOROUGH TOWN CENTR": "SCARBOROUGH TOWN CENTRE",
    "SCARBOROUGH TOWN CENTE": "SCARBOROUGH TOWN CENTRE",
    "SCARBOROUGH TOWN CENT": "SCARBOROUGH TOWN CENTRE",
    "SCARBOROUGH TOWNE CENT": "SCARBOROUGH TOWN CENTRE",
    "SCARBOROUGH CENTER": "SCARBOROUGH CENTRE",
    "SCARBOROUGH CENTR": "SCARBOROUGH CENTRE",
    
    "BRADSTOC AND": "BRADSTOCK AND",
    "BRADSTOC": "BRADSTOCK",
    
    "MORNING SIDE": "MORNINGSIDE",
    "MC COWAN": "MCCOWAN",
    "MC COWNAN": "MCCOWAN",
    "MC COWNA": "MCCOWAN",
    "MC MCCOWAN": "MCCOWAN",
    
    "LAKE SHORE": "LAKESHORE",
    
    "VICTORIA PK ": "VICTORIA PARK ",
    "VICTORIA PAR ": "VICTORIA PARK ",
    "KINGSTON R": "KINGSTON",
    
    "STEELES W": "STEELES",
    "STEELES E": "STEELES",
    "STEELES LO": "STEELES",

    "COLLINSG": "COLLINSGROVE",
    "COLLINSGR": "COLLINSGROVE",
    "MILEPO": "MILEPORT",
    "BETRAND": "BERTRAND",
    "BAMBURG": "BAMBURGH",
    "BAMBERGH": "BAMBURGH",
    "MCGREGOR": "MCGREGOR",
    "MCCREGOR": "MCGREGOR",
    "KIPLINGSTATION": "KIPLING STATION",
    "EGLINTONSTATION": "EGLINTON STATION",
    "ST CLAIRSTATION": "ST CLAIR STATION",
    "WARDENSTATION": "WARDEN STATION",
    
    # Complete station names
    "MAIN STREET STATION": "MAIN STREET",
    "CHRISTIE STATION": "CHRISTIE",
    "SHERBOURNE STATION": "SHERBOURNE",
    "WOODBINE STATION": "WOODBINE",
    "COXWELL STATION": "COXWELL",
    "HIGH PARK STATION": "HIGH PARK",
    "OLD MILL STATION": "OLD MILL",
    "OLD MILLS STATION": "OLD MILL",
    
    # Complete phrase fixes
    "SCARBOROUGH CTR STATIO": "SCARBOROUGH TOWN CENTRE",
    "SCARBOROUGH CENTER STAT": "SCARBOROUGH CENTRE",
    "TERMINAL 3 PEARSON A": "TERMINAL 3 PEARSON AIRPORT",
    "LESTER B PEARSON AIRP": "LESTER B PEARSON AIRPORT",
    "PEARSON AIRPORT TERM": "PEARSON AIRPORT",
    "TORONTO PEARSON AIRPORT": "PEARSON AIRPORT",
    
    # The removals
    "DUND AND": "DUNDAS AND",
    "DANFO AND": "DANFORTH AND",
    "EGLI AND": "EGLINTON AND",

    "FINCHDENE": "FINCHDENE",
    "YORK UNIVER": "YORK UNIVERSITY",
    "HUMBER COLLE": "HUMBER COLLEGE",
    "MORNINGSIDE AND NIGHTSTAR":"MORNINGSIDE AND NIGHTSTAR",
    "AIRPORT AND MORNINGSTAR":"AIRPORT AND MORNINGSTAR",
    "QUEENSWAY DIVSION":"QUEENSWAY DIVISION",
    "MALVERN DIVSION":"MALVERN DIVISION",
    "AMAZOON":"AMAZON",
    "FUFILLMENT":"FULFILLMENT",

    "ST CLAI": "ST CLAIR",
    "MABLLE": "MARBLE",
    "MORNINGSIDE AND NETHER": "MORNINGSIDE AND NETHERBY",
    "SHORTTING": "SHORTING",
    "PARKINGT": "PARKINGTON",
    "FOURTEENT": "FOURTEENTH",
    "SPRINGHUR": "SPRINGHURST",
    "BRAECR": "BRAECREST",
    "COLLINSGROVE AND LAWRE": "COLLINSGROVE AND LAWRENCE",
    "DUNDAS AND MABLLE": "DUNDAS AND MARBLE",
    "BIRCHMOUNT AND MCGREGO": "BIRCHMOUNT AND MCGREGOR",

    # Airports
    "LESTER B PEARSON AIRP": "LESTER B PEARSON AIRPORT",
    "TERMINAL 3 AIRPORT": "TERMINAL 3 PEARSON AIRPORT",
    # Common truncations
    "DRIFTWOOD AND TOPCLIF": "DRIFTWOOD AND TOPCLIFF",
    "METR": "METROPOLITAN",
    "COULTE": "COULTER",
    "NORTHWESTG": "NORTHWEST",
    "HEDDINGTO": "HEDDINGTON",
    "WESTH": "WESTHUMBER",
    "MORNINGSTAR": "MORNINGSTAR",
    "MILITAR": "MILITARY",
    "MIDDLEFIEL": "MIDDLEFIELD",
    "GLENDOWER": "GLENDOWER",
    "BOWOOD": "BAYWOOD",
    "CROHAM": "CROHAM",
    "KAWREBCE": "KAWNEER",
    "GREYAB": "GREYABBEY",
    "ELLESMERE AND MORNINGSTAR":"ELLESMERE AND MORNINGSTAR",
    "FAIRLEIGH": "FAIRLEIGH",
    "FRANK FAU":"FRANK FAUST",
    "CHIMN":"CHIMNEY",
    "IAN MACDONALD":"IAN MCDONALD",
    "FORTIET":"FORTIETH",
    "HUNTINGWOO":"HUNTINGWOOD",
    "LAUGHTON":"LAUGHTON",
    "PORT UNIO":"PORT UNION",
    "GLENCAIRN STATION AND": "GLENCAIRN AND",
    "DANFORTH COXWELL STATION":"DANFORTH AND COXWELL",
    "CONNOR AND PAPE STATION":"CONNOR AND PAPE",   
    "DANFORTH AND DONLANDS STATION":"DANFORTH AND DONLANDS",  
    "MCNICOLL AND MIDLAND STATION":"MCNICOLL AND MIDLAND",  
    "FINCH STATION W AND HWY":"FINCH AND HWY",
    "JANE STATION AND YORKGATE":"JANE AND YORKGATE",

     # Street truncations
    "DUFFERIN AND YORK UNIV": "DUFFERIN AND YORK UNIVERSITY",
    "FINC AND MARTIN GROOVE": "FINCH AND MARTIN GROVE",
    "FINCH AND MARTIN GROOV": "FINCH AND MARTIN GROVE",
    "BIRCHMOUNT AND SILVER": "BIRCHMOUNT AND SILVER STAR",
    "GLEN BELLE": "GLEN BELL",
    "DRIFT AND GRAND RAVINE": "DRIFTWOOD AND GRAND RAVINE",
    "DRIFT AND": "DRIFTWOOD AND",
    "MORNING GR": "MORNINGSIDE",
    "MORNING GRO": "MORNINGSIDE",
    "THORNBECK": "THORNBECK",
    "TERMINAL 3 ARRIVALS":"TERMINAL 3 PEARSON AIRPORT",
    "AIRPORT LOOP ALBION":"PEARSON AIRPORT",
    "BATHU AND": "BATHURST AND",
    "BATHU ": "BATHURST ",
    "CONNOR AND": "OCONNOR AND",
    "O CO AND": "OCONNOR AND",
    "O CONNOR AND": "OCONNOR AND",
    "CARPEN AND": "CARPENTER AND",

    "DON MILLS STATION AND": "DON MILLS AND",
    "MIDLAND STATION AND": "MIDLAND AND",
    "DON MILLS STATION AND EGLINTON": "DON MILLS AND EGLINTON",
    "DON MILLS STATION AND OVERLEA": "DON MILLS AND OVERLEA",
    "DON MILLS STATION AND FINCH": "DON MILLS AND FINCH",
    "DON MILLS STATION AND SHEPPARD": "DON MILLS AND SHEPPARD",
    "DON MILLS STATION AND STEELES": "DON MILLS AND STEELES",
    "DON MILLS STATION AND GATEWAY": "DON MILLS AND GATEWAY",
    "MIDLAND STATION AND SHEPPARD": "MIDLAND AND SHEPPARD",
    "MIDLAND STATION AND ST CLAIR": "MIDLAND AND ST CLAIR",
    "KENNEDY AND MIDLAND STATION": "KENNEDY AND MIDLAND",
    "BLOOR AND ST GEORGE STATION": "BLOOR AND ST GEORGE",
    "BAYVIEW AND YORK MILLS STATION": "BAYVIEW AND YORK MILLS",
    "EGLINTON AND N SER": "EGLINTON AND NORTH SERVICE",
    "EGLINTON AND S SER": "EGLINTON AND SOUTH SERVICE",
    "HWY 40 ": "HWY 400 ",
    "BROWNS LINE AND LAKESH": "BROWNS LINE AND LAKESHORE",
    "MANITOBA AND NOVA SCOT": "MANITOBA AND NOVA SCOTIA",
    "EGLINTON AND HUNTINGTO": "EGLINTON AND HUNTINGWOOD",
    "BLACK CREEK AND TRETHE": "BLACK CREEK AND TRETHEWEY",
    "HERONS HI": "HERONS HILL",
    "BESSBOROU": "BESSBOROUGH",
    "O CONNER": "OCONNOR",
    "CONNOR AND": "OCONNOR AND",
    "ABITIBI": "ABITIBO",
    "HARBOUR AND YONGE": "HARBOURFRONT AND YONGE",
    "SHEPPARD AND YORKLAND": "SHEPPARD AND YORKLAND BLVD",
    "ELLESMERE AND MORNINGSTAR": "ELLESMERE AT MORNINGSTAR",  
    "SHEPPARD W STATION": "SHEPPARD WEST STATION",
    "SHEPPARD W": "SHEPPARD WEST",
    "SHEPPARD WEST STATIONN": "SHEPPARD WEST STATION",
}

ABBREVIATION_FIXES = {
    "LAWRE": "LAWRENCE",
    "LAWRENC": "LAWRENCE",
    "LAWREN": "LAWRENCE",
    "LAWR": "LAWRENCE",
    "LAWR E": "LAWRENCE",
    "DUFFE": "DUFFERIN",
    "EGLIN": "EGLINTON",
    "SHEP": "SHEPPARD",
    "SHEPP": "SHEPPARD",
    "MCNI": "MCNICOLL",
    "PHARM": "PHARMACY",
    "SCARB": "SCARBOROUGH",
    "SCARBORO": "SCARBOROUGH",
    "FIMCH": "FINCH",
    "FINH": "FINCH",
    "MORNING": "MORNINGSIDE",
    "NIGHTS": "NIGHTSTAR",
    "FINCHDEN": "FINCHDENE",
    "UNIV": "UNIVERSITY",
    "UNIVERS": "UNIVERSITY",
    "YORK UNIV": "YORK UNIVERSITY",
    "MCCOWAN": "MCCOWAN",
    "MARTIN GR": "MARTIN GROVE",
    "STEE": "STEELES",
    "HUNTINGWOO": "HUNTINGWOOD",
    "GLEN CEDA": "GLEN CEDAR",
    "SHEP": "SHEPPARD",
    "GREEN VIL": "GREENWIN VILLAGE",
    "GREENWIL": "GREENWIN VILLAGE",
    "COMMISIONERS": "COMMISSIONERS",
    "STEEPROC": "STEEPROCK"
}

STATION_FIXES = {
    "KENNEDY STAT": "KENNEDY STATION",
    "ISLINGTON STATIOM": "ISLINGTON STATION",
    "ISLINGTONSTATION": "ISLINGTON STATION",
    "WILSON STATION GARAGE": "WILSON STATION",
    "WILSON STATION YARD": "WILSON STATION",
    "KING STATION HIGH": "KING STATION",
    "PAPE STATION ROUTE": "PAPE STATION",
    "EGLINTON STATION WEST": "EGLINTON STATION",
    "PIONEER VIILLAGE STATI": "PIONEER VILLAGE STATION",
    "PIONEER VILLAGE STATI": "PIONEER VILLAGE STATION",
    "WARDEN STATION STATYION": "WARDEN STATION",
    "KEEL STATION": "KEELE STATION",
    "SHEPPARD W STATIN": "SHEPPARD WEST STATION",
    "YORKDALE STATION GO TERMINAL": "YORKDALE STATION",
}

SUFFIX_EXPANSIONS = {
    "UNIVER": "UNIVERSITY",
    "COLLE": "COLLEGE",
    "DIVSION": "DIVISION",
    "CRES": "CRESCENT",
}

TOKEN_FIXES = {
    "UNIV":"UNIVERSITY",
    "UNIVER":"UNIVERSITY",
    "GROOV":"GROVE",
    "VIILLAGE":"VILLAGE",
    "VIILL":"VILLAGE",
    "MCNICOLL":"MCNICOLL",
    "MORRISON":"MORRISON",
}

STREET_SYNONYMS = {
    "N SERVICE": "NORTH SERVICE",
    "S SERVICE": "SOUTH SERVICE",
    "BLVD": "BOULEVARD"
}

MANUAL_LOCATION_FIXES = {
    "DON MILLS STATION AND EGLINTON":"DON MILLS AND EGLINTON",
    "DON MILLS STATION AND OVERLEA":"DON MILLS AND OVERLEA",
    "DON MILLS STATION AND FINCH":"DON MILLS AND FINCH",
    "DON MILLS STATION AND SHEPPARD":"DON MILLS AND SHEPPARD",
    "DON MILLS STATION AND STEELES":"DON MILLS AND STEELES",
    "DON MILLS STATION AND GATEWAY":"DON MILLS AND GATEWAY",
    "MIDLAND STATION AND SHEPPARD":"MIDLAND AND SHEPPARD",
    "MIDLAND STATION AND ST CLAIR":"MIDLAND AND ST CLAIR",
    "KENNEDY AND MIDLAND STATION":"KENNEDY AND MIDLAND",
    "BLOOR AND ST GEORGE STATION":"BLOOR AND ST GEORGE",
    "BAYVIEW AND YORK MILLS STATION":"BAYVIEW AND YORK MILLS",
    "O CO AND VICTORIA PARK":"OCONNOR AND VICTORIA PARK",
    "O CONNER AND PAPE":"OCONNOR AND PAPE",
}

def apply_ordered_fixes(text, fixes):
    for old, new in sorted(
        fixes.items(),
        key=lambda x: len(x[0]),
        reverse=True
    ):
        pattern = r"\b{}\b".format(re.escape(old))
        text = re.sub(pattern, new, text)

    return text

def apply_street_synonyms(text):
    for old, new in STREET_SYNONYMS.items():
        text = text.replace(old, new)

    return text
    
def normalize_gtfs_text(text):
    text = text.upper()
    text = text.replace("'", "")
    text = text.replace("-", " ")
    text = text.replace(".", "")

    # 1. Exact phrases first
    text = apply_ordered_fixes(
        text,
        MANUAL_LOCATION_FIXES
    )

    # 2. Station-specific fixes
    text = apply_ordered_fixes(
        text,
        STATION_FIXES
    )

    # 3. Major spelling fixes
    text = apply_ordered_fixes(
        text,
        COMMON_FIXES
    )

    # 4. Safer abbreviations
    text = apply_ordered_fixes(
        text,
        ABBREVIATION_FIXES
    )

    # 5. Token cleanup
    text = apply_ordered_fixes(
        text,
        TOKEN_FIXES
    )

    # 6. Word expansions
    text = apply_ordered_fixes(
        text,
        SUFFIX_EXPANSIONS
    )

    # 7. Street standardization
    text = apply_street_synonyms(text)

    return " ".join(text.split())

stops_df["stop_name_normalized"] = (
    stops_df["stop_name"]
    .apply(normalize_gtfs_text)
)

intersection_lookup = {}
for idx, row in stops_df.iterrows():
    name = row["stop_name_normalized"]
    intersection_lookup.setdefault(
        name,
        []
    ).append(idx)

def normalize_facility_text(text):
    text = normalize_gtfs_text(text)

    replacements = {
        "FINCH STATION WEST": "FINCH STATION",
        "FINCH STATION EAST": "FINCH STATION",

        # Common station typos only
        " STATION STATIO": " STATION",

        # Direction handling
        " STATION W": " STATION WEST",
        " STATION E": " STATION EAST",
        " W STATION": " WEST STATION",
        " E STATION": " EAST STATION",

        # Facility formatting
        " CTR": " CENTRE",
        "CENTR": "CENTRE",
        "TERMIN": "TERMINAL"
    }

    for old, new in replacements.items():
        text = text.replace(old, new)

    return " ".join(text.split())
    
def calculate_bearing(lat1, lon1, lat2, lon2):
    """
    Calculate compass direction from point 1 to point 2
    """
    lat1 = radians(lat1)
    lat2 = radians(lat2)

    diff_lon = radians(lon2 - lon1)

    x = sin(diff_lon) * cos(lat2)

    y = (
        cos(lat1) * sin(lat2)
        -
        sin(lat1) * cos(lat2) * cos(diff_lon)
    )

    bearing = degrees(atan2(x, y))
    return (bearing + 360) % 360

def bearing_to_direction(bearing):

    if bearing >= 315 or bearing < 45:
        return "N"

    elif bearing >= 45 and bearing < 135:
        return "E"

    elif bearing >= 135 and bearing < 225:
        return "S"

    else:
        return "W"
        
def extract_intersection_streets(text):

    text = normalize_gtfs_text(text)
    text = text.replace(
        " STATION",
        ""
    )
    parts = text.split(" AND ")

    if len(parts) != 2:
        return []

    street1 = parts[0].strip()
    street2 = parts[1].strip()

    # reject incomplete intersections
    if len(street1) < 3 or len(street2) < 3:
        return []

    return [
        street1,
        street2
    ]
    
def intersection_candidates(location_text):
    streets = extract_intersection_streets(
        location_text
    )
    if len(streets) != 2:
        return []

    s1 = normalize_gtfs_text(streets[0])
    s2 = normalize_gtfs_text(streets[1])
    exact_candidates = []
    fuzzy_candidates = []
    
    for stop_name, idx_list in intersection_lookup.items():
        stop_tokens = stop_name.split()
    
        street1_match = any(
            s1 == token or s1 in stop_name
            for token in stop_tokens
        )
    
        street2_match = any(
            s2 == token or s2 in stop_name
            for token in stop_tokens
        )
    
        if street1_match and street2_match:
            exact_candidates.extend(idx_list)
            continue

        # fuzzy fallback
        score1 = ratio(s1, stop_name)
        score2 = ratio(s2, stop_name)

        if score1 >= 70 and score2 >= 75:
            fuzzy_candidates.extend(idx_list)

    if exact_candidates:
        return exact_candidates

    return fuzzy_candidates

facility_lookup = stops_df.copy()

facility_lookup["stop_name_normalized"] = (
    facility_lookup["stop_name"]
    .apply(normalize_facility_text)
)

def facility_candidates(location_text):

    text = normalize_facility_text(location_text)
    candidates = []

    # Exact match first
    exact = []

    for idx, row in facility_lookup.iterrows():

        stop_name = row["stop_name_normalized"]

        if text == stop_name:
            exact.append(idx)

    if exact:
        return exact


    # Containment + fuzzy
    for idx, row in facility_lookup.iterrows():

        stop_name = row["stop_name_normalized"]


        # Station protection
        if "STATION" in text and "STATION" in stop_name:

            text_tokens = set(
                text.replace(
                    "STATION",
                    ""
                ).split()
            )

            stop_tokens = set(
                stop_name.replace(
                    "STATION",
                    ""
                ).split()
            )

            # Require station name overlap
            if not text_tokens.intersection(stop_tokens):
                continue

        # Containment
        if text in stop_name or stop_name in text:
            candidates.append(idx)
            continue

        if "LOOP" in text and "LOOP" in stop_name:
            candidates.append(idx)
            continue

        # Fuzzy
        score = ratio(
            text,
            stop_name
        )

        if score >= 90:
            candidates.append(idx)

    return candidates

def select_facility_stop(candidate_indices, location_text):

    if not candidate_indices:
        return None

    scored = []

    location_clean = normalize_facility_text(
        location_text
    ).upper()

    for idx in candidate_indices:

        raw_name = facility_lookup.loc[
            idx,
            "stop_name"
        ]

        name = normalize_facility_text(
            raw_name
        ).upper()

        score = 0


        # -----------------------------------
        # 1. Exact normalized match
        # -----------------------------------
        if location_clean == name:
            score += 300


        # -----------------------------------
        # 2. Prefer main station names
        # -----------------------------------
        if name.endswith(" STATION"):
            score += 200

        elif " STATION" in name:
            score += 10


        # -----------------------------------
        # 3. Station-specific protection
        # -----------------------------------
        if "FINCH STATION" in location_clean:

            if name == "FINCH STATION":
                score += 100

            elif name.startswith(
                "FINCH STATION"
            ):
                score += 30

            if "FINCH WEST" in name:
                score -= 150

            if "JANE AND FINCH" in name:
                score -= 150

            if "NORFINCH" in name:
                score -= 150



        # -----------------------------------
        # 4. Penalize detailed locations
        # -----------------------------------
        penalties = {
            "PARKING": -100,
            "LOT": -100,
            "PLATFORM": -80,
            "BUS BAY": -150,
            "BAY": -100,
            "DROP OFF": -50,
            "LOOP": -40,
            "TERMINAL": -30
        }

        for word, penalty in penalties.items():

            if word in name:
                score += penalty



        # -----------------------------------
        # 5. Remove GTFS detail suffixes
        # -----------------------------------
        clean_name = name

        remove_parts = [
            " - SOUTHBOUND PLATFORM",
            " - NORTHBOUND PLATFORM",
            " - WESTBOUND PLATFORM",
            " - EASTBOUND PLATFORM",
            " - SUBWAY PLATFORM",
            " BUS BAY 1",
            " BUS BAY 2",
            " BUS BAY 3",
            " BUS BAY 4",
            " BUS BAY 5",
            " BUS BAY 6"
        ]

        for part in remove_parts:
            clean_name = clean_name.replace(
                part,
                ""
            )

        clean_name = clean_name.strip()


        if location_clean == clean_name:
            score += 200



        # -----------------------------------
        # 6. Prefer shorter cleaner names
        # -----------------------------------
        if len(name) > 50:
            score -= 5

        scored.append(
            (idx, score)
        )


    best_idx, best_score = max(
        scored,
        key=lambda x: x[1]
    )


    row = facility_lookup.loc[
        best_idx
    ]

    return {
        "stop_index": best_idx,
        "stop_id": row["stop_id"],
        "stop_name": row["stop_name"],
        "score": best_score
    }
    
def get_route_directions(location_id, route):
    try:
        location_id = int(location_id)
    except:
        return {}

    key = (
        location_id,
        str(route)
    )

    if key not in direction_lookup:
        return {}

    history = direction_lookup[key]

    return {
        k:v
        for k,v in history.items()
        if k != "UNKNOWN"
    }

def get_direction_score(location_id, route, candidate_direction):
    history = get_route_directions(
        location_id,
        route
    )

    if not history:
        return 0

    total = sum(history.values())

    return history.get(
        candidate_direction,
        0
    ) / total

def stop_quality_score(stop_name):
    name = stop_name.upper()
    score = 0
    
    # Prefer normal stops
    if " AT " in name:
        score += 10
    
    # Penalize special locations
    SPECIAL_WORDS = [
        "AMAZON",
        "SHOPPING",
        "MALL",
        "CENTRE",
        "LOOP"
    ]

    for word in SPECIAL_WORDS:
        if word in name:
            score -= 5
        
    if "WEST SIDE" in name:
        score -= 5
        
    return score

def candidate_score(
    stop_idx,
    location_id,
    route
):
    row = stops_df.loc[stop_idx]
    score = 0
    stop_id = row["stop_id"]

    # 1. Route match (bonus only, NOT rejection)
    routes_at_stop = stop_routes.get(
        stop_id,
        set()
    )

    if route is not None:
        if str(route) in routes_at_stop:
            score += 10

    # 2. Stop quality
    score += stop_quality_score(
        row["stop_name"]
    )

    # 3. Direction history
    # if stop_idx in bearing_direction:

    #     stop_direction = bearing_direction[stop_idx]

    #     score += (
    #         get_direction_score(
    #             location_id,
    #             route,
    #             stop_direction
    #         ) * 20
    #     )

    # 4. GTFS usage
    usage = stop_usage.get(
        stop_id,
        0
    )

    score += min(
        usage / 500,
        5
    )

    return score

def select_best_stop(
    candidate_indices,
    location_id,
    route
):

    scored = []
    for idx in candidate_indices:

        score = candidate_score(
            idx,
            location_id,
            route
        )

        scored.append(
            (idx, score)
        )

    # remove rejected candidates
    scored = [
        x for x in scored
        if x[1] > -999
    ]

    if len(scored) == 0:
        return None

    # highest score wins
    best_idx, best_score = max(
        scored,
        key=lambda x:x[1]
    )

    return {
        "stop_index": best_idx,
        "stop_id": stops_df.loc[best_idx,"stop_id"],
        "stop_name": stops_df.loc[best_idx,"stop_name"],
        "score": best_score
    }

def stop_serves_route(stop_idx, route):

    if route is None:
        return True

    stop_id = stops_df.loc[
        stop_idx,
        "stop_id"
    ]

    routes = stop_routes.get(
        stop_id,
        set()
    )

    return str(route) in routes

def match_incident_to_stop(
    location_id,
    location_text,
    route
):
    # Normalize once for matching decisions
    normalized_location = normalize_gtfs_text(
        location_text
    )

    # Step 1: intersection recovery
    clean_for_intersection = (
        normalized_location
        .replace(" STATION", "")
        .strip()
    )
    
    intersection = intersection_candidates(
        clean_for_intersection
    )
    
    if intersection:
        best = select_best_stop(
            intersection,
            location_id,
            route
        )
    
        if best:
            if stop_serves_route(
                best["stop_index"],
                route
            ):
                return {
                    "match_status": "MATCHED_INTERSECTION",
                    **best
                }

    location_category = classify_no_match(location_text)

    if location_category == "FACILITY_LOCATION":
        
        facility = facility_candidates(normalized_location)
    
        if facility:
            best = select_facility_stop(
                facility,
                location_text
            )
    
            if best:
                return {
                    "match_status": "MATCHED_FACILITY",
                    **best
                }
            
    # Step 1: extract streets
    streets = clean_gtfs_tokens(location_text)

    if len(streets) != 2:
        return {
            "match_status": "NO_STREET_MATCH",
            "stop_id": None
        }

    # Step 2: recover spelling + candidates
    result = get_street_candidates_with_recovery(
        streets
    )

    candidates = result["candidates"]

    if len(candidates) == 0:
        return {
            "match_status": "NO_STREET_MATCH",
            "stop_id": None
        }


    # Step 3: check route-serving candidates
    route_candidates = []

    for idx in candidates:

        stop_id = stops_df.loc[idx,"stop_id"]

        routes = stop_routes.get(
            stop_id,
            set()
        )

        if str(route) in routes:
            route_candidates.append(idx)


    # Step 4: route match exists
    if len(route_candidates) > 0:

        best = select_best_stop(
            route_candidates,
            location_id,
            route
        )

        return {
            "match_status": "MATCHED_ROUTE",
            **best
        }

    # Step 5: street match only
    best = select_best_stop(
        candidates,
        location_id,
        route=None
    )
    
    if best:
        return {
            "match_status": "MATCHED_STOP_ONLY",
            **best
        }
    
    return {
        "match_status": "NO_STOP_SELECTED",
        "stop_id": None
    }

def classify_no_match(location):

    name = location.upper().strip()

    if name in [
        "UNKNOWN",
        "ENTIRE ROUTE"
    ]:
        return "INVALID_LOCATION"


    # Remove station noise first
    cleaned = (
        name
        .replace("STATION", "")
        .replace("  ", " ")
        .strip()
    )


    # If it still contains two streets, treat as intersection
    if "AND" in cleaned:
        return "INTERSECTION_RECOVERY"


    facility_words = [
        "GARAGE",
        "YARD",
        "DIVISION",
        "LOOP"
    ]

    if any(word in name for word in facility_words):
        return "FACILITY_LOCATION"


    # Single station names are usually facilities
    if "STATION" in name:
        return "FACILITY_LOCATION"


    return "STREET_RECOVERY"

# %%
results = []

total = len(route_location_lookup)

for i, (_, row) in enumerate(route_location_lookup.iterrows()):

    if i % 100 == 0:
        print(f"{i}/{total}")

    result = match_incident_to_stop(
        row["location_id"],
        row["location"],
        row["route"]
    )

    results.append({
        "location_id": row["location_id"],
        "route": row["route"],
        "location": row["location"],
        "stop_id": result.get("stop_id"),
        "stop_name": result.get("stop_name"),
        "match_status": result.get("match_status"),
        "match_score": result.get("score")
    })

location_stop_lookup = pd.DataFrame(results)
# Out:
# 0/17904
# 100/17904
# 200/17904
# 300/17904
# 400/17904
# 500/17904
# 600/17904
# 700/17904
# 800/17904
# 900/17904
# 1000/17904
# 1100/17904
# 1200/17904
# 1300/17904
# 1400/17904
# 1500/17904
# 1600/17904
# 1700/17904
# 1800/17904
# 1900/17904
# 2000/17904
# 2100/17904
# 2200/17904
# 2300/17904
# 2400/17904
# 2500/17904
# 2600/17904
# 2700/17904
# 2800/17904
# 2900/17904
# 3000/17904
# 3100/17904
# 3200/17904
# 3300/17904
# 3400/17904
# 3500/17904
# 3600/17904
# 3700/17904
# 3800/17904
# 3900/17904
# 4000/17904
# 4100/17904
# 4200/17904
# 4300/17904
# 4400/17904
# 4500/17904
# 4600/17904
# 4700/17904
# 4800/17904
# 4900/17904
# 5000/17904
# 5100/17904
# 5200/17904
# 5300/17904
# 5400/17904
# 5500/17904
# 5600/17904
# 5700/17904
# 5800/17904
# 5900/17904
# 6000/17904
# 6100/17904
# 6200/17904
# 6300/17904
# 6400/17904
# 6500/17904
# 6600/17904
# 6700/17904
# 6800/17904
# 6900/17904
# 7000/17904
# 7100/17904
# 7200/17904
# 7300/17904
# 7400/17904
# 7500/17904
# 7600/17904
# ...

# %%
#------check 
location_stop_lookup["match_status"].value_counts()

location_stop_lookup[
    location_stop_lookup["match_status"] == "MATCHED_STOP_ONLY"
].head(20)

location_stop_lookup[
    location_stop_lookup["location"].isin(
        [
            "BATHURST AND DUNDAS STATION",
            "FINCH STATION",
            "BIRCHMOUNT GARAGE",
            "DON MILLS STATION AND EGLINTON"
        ]
    )
][
    [
        "location",
        "route",
        "stop_name",
        "match_status"
    ]
]
# Out:
#                              location  route  \
# 0         BATHURST AND DUNDAS STATION      7
# 1                   BIRCHMOUNT GARAGE      7
# 3                       FINCH STATION      7
# 486                     FINCH STATION     11
# 736                 BIRCHMOUNT GARAGE     12
# 996                 BIRCHMOUNT GARAGE     24
# 1282   DON MILLS STATION AND EGLINTON     25
# 2231   DON MILLS STATION AND EGLINTON     32
# 2235                    FINCH STATION     32
# 2904   DON MILLS STATION AND EGLINTON     34
# 2908                    FINCH STATION     34
# 3696                    FINCH STATION     36
# 4583                    FINCH STATION     38
# 4875                    FINCH STATION     39
# 5910                    FINCH STATION     43
# 6162                    FINCH STATION     45
# 6879                    FINCH STATION     52
# 7685                    FINCH STATION     53
# 8121   DON MILLS STATION AND EGLINTON     54
# 8123                    FINCH STATION     54
# ...

# %%
location_stop_lookup = location_stop_lookup.merge(
    stops_df[
        [
            "stop_id",
            "stop_lat",
            "stop_lon"
        ]
    ],
    on="stop_id",
    how="left"
)

# %%
location_stop_lookup[
    [
        "stop_lat",
        "stop_lon"
    ]
].isna().sum()
# Out:
# stop_lat    6872
# stop_lon    6872
# dtype: int64

# %%
location_stop_lookup["serves_route"] = None
for i, row in location_stop_lookup.iterrows():

    if pd.isna(row["stop_id"]):
        continue

    routes = stop_routes.get(
        int(row["stop_id"]),
        set()
    )

    location_stop_lookup.loc[
        i,
        "serves_route"
    ] = str(row["route"]) in routes

location_stop_lookup[
    "serves_route"
].value_counts(dropna=False)
# Out:
# serves_route
# None     6872
# True     6023
# False    5009
# Name: count, dtype: int64

# %%
wrong_route = location_stop_lookup[
    location_stop_lookup["serves_route"] == False
]

wrong_route[
    [
        "location",
        "route",
        "stop_id",
        "stop_name",
        "match_status"
    ]
].head(50)
# Out:
#                          location  route  stop_id  \
# 0     BATHURST AND DUNDAS STATION      7   6009.0
# 1               BIRCHMOUNT GARAGE      7  99922.0
# 3                   FINCH STATION      7  99992.0
# 4              BLOOR AND DUFFERIN      7   7761.0
# 5              BATHURST AND BLOOR      7  10403.0
# 8      SCARBOROUGH CENTRE STATION      7  99929.0
# 9           VICTORIA PARK STATION      7   4023.0
# 10             EGLINTON W STATION      7  99993.0
# 11             DAVISVILLE STATION      7  99997.0
# 12             YORK MILLS STATION      7   2126.0
# 13               YORKDALE STATION      7   4681.0
# 14                 WILSON STATION      7  99966.0
# 15                COXWELL STATION      7  14859.0
# 19            WILSON STATION YARD      7  99966.0
# 20          DUFFERIN AND EGLINTON      7  39375.0
# 21              STEELES AND YONGE      7   8844.0
# 22             SHEPPARD W STATION      7   6160.0
# 23             ROYAL YORK STATION      7  99940.0
# ...

# %%
powerbi_locations = location_stop_lookup[
    [
        "location",
        "location_id",
        "stop_name",
        "stop_lat",
        "stop_lon",
        "match_status",
        "route",
        "serves_route"
    ]
]

powerbi_locations.to_csv(
    "output/location_stop_lookup_powerbi.csv",
    index=False
)

# %%
route_location_lookup[
    ["route", "location_id"]
].duplicated().sum()
# Out:
# np.int64(0)

# %%
# routes_per_location = (route_location_lookup.groupby("location_id")["route"].apply(lambda x: x.astype(str).tolist()).to_dict())

# # normalization function
# COMMON_FIXES = {
#     # Original fixes
#     "THORNCLIFF": "THORNCLIFFE",
#     "LOCKPO": "LOCKPORT",
#     "L AMORE": "LAMORE",
#     "ST MATTHEW": "ST MATTHEWS",
#     "TRITION": "TRITON",
#     "BOROUGHQ": "BOROUGH",
#     "BOROUG": "BOROUGH",
#     "BOUROUGH": "BOROUGH",
#     "KNIFGHTSB": "KNIGHTSBRIDGE",
#     "KNIGHTSBR": "KNIGHTSBRIDGE",
#     "EDLIOU": "EDILOU",
#     "HRONER": "HORNER",
#     "MCNICOL": "MCNICOLL",
#     "NAIRIN": "NAIRN",
#     "ABOT": "ABBOT",
#     "ABBEY": "ABBEY",
    
#     # New fixes - complete words/phrases only
#     "THORNECLIF": "THORNCLIFFE",
#     "THORNECLIFFE": "THORNCLIFFE",
#     "THORNCLIF": "THORNCLIFFE",
#     "THORNCLIIF": "THORNCLIFFE",
#     "THRONCLIFF": "THORNCLIFFE",
#     "THRONCLIFFE": "THORNCLIFFE",
#     "THOTNCLIFF": "THORNCLIFFE",
#     "THORNCILFFE": "THORNCLIFFE",
#     "THORCLIFF": "THORNCLIFFE",
#     "THORNCIFFE": "THORNCLIFFE",
#     "THORNCLIFE": "THORNCLIFFE",
#     "THORNCILFF": "THORNCLIFFE",
#     "THRONECLIF": "THORNCLIFFE",
#     "THORNCLLIFFE": "THORNCLIFFE",
    
#     "MARTIN GROV": "MARTIN GROVE",
#     "MARTIN GR": "MARTIN GROVE",
#     "MARTIN GRO": "MARTIN GROVE",
#     "MARTIN GROV": "MARTIN GROVE",
#     "MRTIN GROVE": "MARTIN GROVE",
#     "MARTING GROVE": "MARTIN GROVE",
#     "MARTIN GROOVE": "MARTIN GROVE",
    
#     "LAWRENCE STATION W": "LAWRENCE",
#     "LAWRENCE STATION E": "LAWRENCE",
#     "LAWRENCE STATION": "LAWRENCE",
    
#     "ST CLAIR STATION W": "ST CLAIR",
#     "ST CLAIR STATION": "ST CLAIR",
    
#     "BLOO AND": "BLOOR AND",
#     "DANF AND": "DANFORTH AND",
#     "DANFORTH AV": "DANFORTH",
    
#     "EGLINTON W": "EGLINTON",
#     "EGLINTON E": "EGLINTON",
#     "EGLINTON W STATION": "EGLINTON",
    
#     "FINCH W": "FINCH",
#     "FINCH E": "FINCH",
#     "FINCH STATION W": "FINCH",
#     "FINCH STATION E": "FINCH",
#     "FINCH STATION": "FINCH",
    
#     "KENNEDY STATION AND": "KENNEDY AND",
#     "KENNEDY STATION": "KENNEDY",
    
#     "ISLINGTON STATION AND": "ISLINGTON AND",
#     "ISLINGTON STATION": "ISLINGTON",
    
#     "DUFFERIN STATION AND": "DUFFERIN AND",
#     "DUFFERIN STATION": "DUFFERIN",
    
#     "BATHURST STATION AND": "BATHURST AND",
#     "BATHURST STATION": "BATHURST",
    
#     "WILSON STATION AND": "WILSON AND",
#     "WILSON STATION": "WILSON",
    
#     "QUEEN STATION AND": "QUEEN AND",
#     "QUEEN STATION": "QUEEN",
    
#     "KING STATION AND": "KING AND",
#     "KING STATION": "KING",
    
#     "PIONNER VILLAGE": "PIONEER VILLAGE",
#     "PIONNEER VILLAGE": "PIONEER VILLAGE",
#     "PIONVEER VILLAGE": "PIONEER VILLAGE",
#     "PIOEER VILLAGE": "PIONEER VILLAGE",
#     "PIONIER VILLAGE": "PIONEER VILLAGE",
#     "PIOPNEER VILLAGE": "PIONEER VILLAGE",
#     "PIONER VILLAGE": "PIONEER VILLAGE",
    
#     "SCARBOROUGH TOWN CENTR": "SCARBOROUGH TOWN CENTRE",
#     "SCARBOROUGH TOWN CENTE": "SCARBOROUGH TOWN CENTRE",
#     "SCARBOROUGH TOWN CENT": "SCARBOROUGH TOWN CENTRE",
#     "SCARBOROUGH TOWNE CENT": "SCARBOROUGH TOWN CENTRE",
#     "SCARBOROUGH CENTER": "SCARBOROUGH CENTRE",
#     "SCARBOROUGH CENTR": "SCARBOROUGH CENTRE",
    
#     "BRADSTOC AND": "BRADSTOCK AND",
#     "BRADSTOC": "BRADSTOCK",
    
#     "MORNING SIDE": "MORNINGSIDE",
#     "MC COWAN": "MCCOWAN",
#     "MC COWNAN": "MCCOWAN",
#     "MC COWNA": "MCCOWAN",
#     "MC MCCOWAN": "MCCOWAN",
    
#     "LAKE SHORE": "LAKESHORE",
    
#     "VICTORIA P": "VICTORIA PARK",
#     "VICTORIA PK": "VICTORIA PARK",
#     "VICTORIA PAR": "VICTORIA PARK",
    
#     "KINGSTON R": "KINGSTON",
    
#     "STEELES W": "STEELES",
#     "STEELES E": "STEELES",
#     "STEELES LO": "STEELES",

#     "COLLINSG": "COLLINSGROVE",
#     "COLLINSGR": "COLLINSGROVE",
#     "MILEPO": "MILEPORT",
#     "BETRAND": "BERTRAND",
#     "BAMBURG": "BAMBURGH",
#     "BAMBERGH": "BAMBURGH",
#     "MCGREGOR": "MCGREGOR",
#     "MCCREGOR": "MCGREGOR",
#     "KIPLINGSTATION": "KIPLING STATION",
#     "EGLINTONSTATION": "EGLINTON STATION",
#     "ST CLAIRSTATION": "ST CLAIR STATION",
#     "WARDENSTATION": "WARDEN STATION",
    
#     # Complete station names
#     "MAIN STREET STATION": "MAIN STREET",
#     "CHRISTIE STATION": "CHRISTIE",
#     "SHERBOURNE STATION": "SHERBOURNE",
#     "WOODBINE STATION": "WOODBINE",
#     "COXWELL STATION": "COXWELL",
#     "HIGH PARK STATION": "HIGH PARK",
#     "OLD MILL STATION": "OLD MILL",
#     "OLD MILLS STATION": "OLD MILL",
    
#     # Complete phrase fixes
#     "SCARBOROUGH CTR STATIO": "SCARBOROUGH TOWN CENTRE",
#     "SCARBOROUGH CENTER STAT": "SCARBOROUGH CENTRE",
#     "TERMINAL 3 PEARSON A": "TERMINAL 3 PEARSON AIRPORT",
#     "LESTER B PEARSON AIRP": "LESTER B PEARSON AIRPORT",
#     "PEARSON AIRPORT TERM": "PEARSON AIRPORT",
#     "TORONTO PEARSON AIRPORT": "PEARSON AIRPORT",
    
#     # The removals
#     "DUND AND": "DUNDAS AND",
#     "DANFO AND": "DANFORTH AND",
#     "EGLI AND": "EGLINTON AND",

#     "FINCHDENE": "FINCHDENE",
#     "YORK UNIVER": "YORK UNIVERSITY",
#     "HUMBER COLLE": "HUMBER COLLEGE",
#     "MORNINGSIDE AND NIGHTSTAR":"MORNINGSIDE AND NIGHTSTAR",
#     "AIRPORT AND MORNINGSTAR":"AIRPORT AND MORNINGSTAR",
#     "QUEENSWAY DIVSION":"QUEENSWAY DIVISION",
#     "MALVERN DIVSION":"MALVERN DIVISION",
#     "AMAZOON":"AMAZON",
#     "FUFILLMENT":"FULFILLMENT",

#     "ST CLAI": "ST CLAIR",
#     "MABLLE": "MARBLE",
#     "MORNINGSIDE AND NETHER": "MORNINGSIDE AND NETHERBY",
#     "SHORTTING": "SHORTING",
#     "PARKINGT": "PARKINGTON",
#     "FOURTEENT": "FOURTEENTH",
#     "SPRINGHUR": "SPRINGHURST",
#     "W": "WEST",
#     "BRAECR": "BRAECREST",
#     "COLLINSGROVE AND LAWRE": "COLLINSGROVE AND LAWRENCE",
#     "MILEPO": "MILEPORT",
#     "DUNDAS AND MABLLE": "DUNDAS AND MARBLE",
#     "BIRCHMOUNT AND MCGREGO": "BIRCHMOUNT AND MCGREGOR",

#     # Airports
#     "LESTER B PEARSON AIRP": "LESTER B PEARSON AIRPORT",
#     "TERMINAL 3 AIRPORT": "TERMINAL 3 PEARSON AIRPORT",
#     # Common truncations
#     "DRIFTWOOD AND TOPCLIF": "DRIFTWOOD AND TOPCLIFF",
#     "DRIFTWOOD AND TOPCLIFF": "DRIFTWOOD AND TOPCLIFF",
#     "METR": "METROPOLITAN",
#     "COULTE": "COULTER",
#     "NORTHWESTG": "NORTHWEST",
#     "HEDDINGTO": "HEDDINGTON",
#     "WESTH": "WESTHUMBER",
#     "MORNINGSTAR": "MORNINGSTAR",
#     "MILITAR": "MILITARY",
#     "MIDDLEFIEL": "MIDDLEFIELD",
#     "GLENDOWER": "GLENDOWER",
#     "BOWOOD": "BAYWOOD",
#     "CROHAM": "CROHAM",
#     "KAWREBCE": "KAWNEER",
#     "GREYAB": "GREYABBEY",
#     "ELLESMERE AND MORNINGSTAR":"ELLESMERE AND MORNINGSTAR",
#     "FAIRLEIGH": "FAIRLEIGH",
#     "FRANK FAU":"FRANK FAUST",
#     "CHIMN":"CHIMNEY",
#     "IAN MACDONALD":"IAN MCDONALD",
#     "FORTIET":"FORTIETH",
#     "HUNTINGWOO":"HUNTINGWOOD",
#     "LAUGHTON":"LAUGHTON",
#     "PORT UNIO":"PORT UNION",
#     "GLENCAIRN STATION AND": "GLENCAIRN AND",
#     "DANFORTH COXWELL STATION":"DANFORTH AND COXWELL",
#     "CONNOR AND PAPE STATION":"CONNOR AND PAPE",   
#     "DANFORTH AND DONLANDS STATION":"DANFORTH AND DONLANDS",  
#     "MCNICOLL AND MIDLAND STATION":"MCNICOLL AND MIDLAND",  
#     "FINCH STATION W AND HWY":"FINCH AND HWY",
#     "JANE STATION AND YORKGATE":"JANE AND YORKGATE",

#      # Street truncations
#     "DUFFERIN AND YORK UNIV": "DUFFERIN AND YORK UNIVERSITY",
#     "FINC AND MARTIN GROOVE": "FINCH AND MARTIN GROVE",
#     "FINCH AND MARTIN GROOV": "FINCH AND MARTIN GROVE",
#     "BIRCHMOUNT AND SILVER": "BIRCHMOUNT AND SILVER STAR",
#     "GLEN BELLE": "GLEN BELL",
#     "DRIFT AND GRAND RAVINE": "DRIFTWOOD AND GRAND RAVINE",
#     "MORNING GR": "MORNINGSIDE",
#     "MORNING GRO": "MORNINGSIDE",
#     "THORNBECK": "THORNBECK",
#     "TERMINAL 3 ARRIVALS":"TERMINAL 3 PEARSON AIRPORT",
#     "AIRPORT LOOP ALBION":"PEARSON AIRPORT",
#     "PEARSON":"PEARSON AIRPORT",
# }

# ABBREVIATION_FIXES = {
#     "LAWRE": "LAWRENCE",
#     "LAWRENC": "LAWRENCE",
#     "LAWREN": "LAWRENCE",
#     "LAWR E": "LAWRENCE",
#     "DUF": "DUFFERIN",
#     "DUFF": "DUFFERIN",
#     "DUFFE": "DUFFERIN",
#     "EGL": "EGLINTON",
#     "EGLIN": "EGLINTON",
#     "FINC": "FINCH",
#     "KENN": "KENNEDY",
#     "SHEP": "SHEPPARD",
#     "SHEPP": "SHEPPARD",
#     "MCNI": "MCNICOLL",
#     "PHARM": "PHARMACY",
#     "SCARB": "SCARBOROUGH",
#     "SCARBORO": "SCARBOROUGH",
#     "YONG": "YONGE",
#     "FIMCH": "FINCH",
#     "FINH": "FINCH",
#     "MORNING": "MORNINGSIDE",
#     "NIGHTS": "NIGHTSTAR",
#     "FINCHDEN": "FINCHDENE",
#     "UNIV": "UNIVERSITY",
#     "UNIVERS": "UNIVERSITY",
#     "YORK UNIV": "YORK UNIVERSITY",
#     "MCCOWAN": "MCCOWAN",
#     "MARTIN GR": "MARTIN GROVE",
#     "STEE": "STEELES",
#     "HUNTINGWOO": "HUNTINGWOOD",
#     "GLEN CEDA": "GLEN CEDAR",
#     "SHEP": "SHEPPARD",
#     "MORN": "MORNINGSIDE",
# }

# STATION_FIXES = {
#     "KENNEDY STAT": "KENNEDY STATION",
#     "ISLINGTON STATIOM": "ISLINGTON STATION",
#     "ISLINGTONSTATION": "ISLINGTON STATION",
#     "WILSON STATION GARAGE": "WILSON STATION",
#     "WILSON STATION YARD": "WILSON STATION",
#     "KING STATION HIGH": "KING STATION",
#      "PAPE STATION ROUTE": "PAPE STATION",
#     "EGLINTON STATION WEST": "EGLINTON STATION",
#     "PIONEER VIILLAGE STATI": "PIONEER VILLAGE STATION",
#     "PIONEER VILLAGE STATI": "PIONEER VILLAGE STATION",
#     "WARDEN STATION STATYION": "WARDEN STATION",
#     "KEEL STATION": "KEELE STATION",
#     "SHEPPARD W STATIN": "SHEPPARD WEST STATION",
#     "YORKDALE STATION GO TERMINAL": "YORKDALE STATION",
# }

# SUFFIX_EXPANSIONS = {
#     "UNIVER": "UNIVERSITY",
#     "COLLE": "COLLEGE",
#     "HOS": "HOSPITAL",
#     "STATIO": "STATION",
#     "DIVSION": "DIVISION",
#     "TERM": "TERMINAL",
#     "CRES": "CRESCENT",
# }

# TOKEN_FIXES = {
#     "UNIV":"UNIVERSITY",
#     "UNIVER":"UNIVERSITY",
#     "FINC":"FINCH",
#     "DUF":"DUFFERIN",
#     "MORN":"MORNINGSIDE",
#     "GR":"GROVE",
#     "GROOV":"GROVE",
#     "STEE":"STEELES",
#     "STATI":"STATION",
#     "STN":"STATION",
#     "VIILLAGE":"VILLAGE",
#     "VIILL":"VILLAGE",
#     "MCNICOLL":"MCNICOLL",
#     "MORRISON":"MORRISON",
# }

# def token_normalize(text):
#     words=text.split()
#     words=[
#         TOKEN_FIXES.get(w,w)
#         for w in words
#     ]
#     return " ".join(words)
    
# def normalize_location_combined(text):
#     if not isinstance(text, str):
#         return ""

#     text = text.upper().strip()
#     text=token_normalize(text)
#     # 1. station exact fixes
#     if text in STATION_FIXES:
#         text = STATION_FIXES[text]

#     # 2. abbreviation exact fixes
#     if text in ABBREVIATION_FIXES:
#         text = ABBREVIATION_FIXES[text]

#     # 3. typo corrections
#     for old, new in COMMON_FIXES.items():
#         text = re.sub(
#             rf"\b{re.escape(old)}\b",
#             new,
#             text
#         )

#     # 5. controlled suffix expansion
#     for old, new in SUFFIX_EXPANSIONS.items():
#         text = re.sub(
#             rf"\b{re.escape(old)}\b",
#             new,
#             text
#         )

#     # 6. operational suffix cleanup
#     for r in [" STN", " BUS BAY", " PLATFORM"]:
#         text = text.replace(r, "")

#     # 7. intersection standardization
#     text = re.sub(r"\bAND\b", "&", text)
#     text = re.sub(r"\bAT\b", "&", text)

#     text = re.sub(r"\s+", " ", text)
#     return text.strip()

# def clean_station(text):
#     """Clean station names for fuzzy matching - keep station names intact for better matching"""
#     if not isinstance(text, str):
#         return ""
#     text = text.upper()
#     replacements = [
#         " STATION",
#         " STN",
#         " TERMINAL",
#         " SUBWAY",
#         " BUS BAY",
#         " LOOP",
#         " PLATFORM",
#         " WB",
#         " EB",
#         " NB",
#         " SB"
#     ]
#     for r in replacements:
#         text = text.replace(r, "")
#     # remove punctuation
#     text = re.sub(r"[^A-Z0-9& ]", "", text)
#     text = re.sub(r"\s+", " ", text)
#     return text.strip()

# def canonical_intersection(text):
#     text = normalize_location_combined(text)
#     if "&" not in text:
#         return None

#     parts = text.split("&")
#     if len(parts) != 2:
#         return None

#     streets = []
#     for p in parts:
#         p = re.sub(
#             r"\b(ST|STREET|RD|ROAD|AVE|AV|AVENUE|DR|DRIVE|BLVD|BOULEVARD|HWY|HIGHWAY|EAST|WEST|NORTH|SOUTH)\b",
#             "",
#             p
#         )
#         p = re.sub(r"\s+", " ", p)
#         p = p.strip()

#         if p:
#             streets.append(p)
#     if len(streets) == 2:
#         return "|".join(sorted(streets))
#     return None

# # Drop stops with missing coordinates
# stops_df = stops_df.dropna(subset=['stop_lat', 'stop_lon'])
# print(f"Loaded {len(stops_df)} GTFS stops with valid coordinates")
# print(f"Loaded {len(unique_df)} unique locations")
# print(f"Loaded {len(ml_df)} ML rows")

# # Keep only locations that belong to the selected routes
# unique_df = unique_df[
#     unique_df["location_id"].isin(route_location_lookup["location_id"])
# ].copy()
# # Attach route list
# unique_df["routes_list"] = unique_df["location_id"].map(routes_per_location)
# # Selected routes only
# valid_route_ids = set(route_location_lookup["route"].astype(str).unique())
# print(f"Locations to match: {len(unique_df)}")
# print(f"Selected routes: {len(valid_route_ids)}")

# # Normalise GTFS stop names and build exact lookup
# print("Normalising GTFS stops")
# tqdm.pandas(desc="Normalising GTFS")
# stops_df['normalized'] = stops_df['stop_name'].progress_apply(normalize_location_combined)

# # Regular exact lookup
# gtfs_lookup = {}  # normalized_key -> (stop_name, lat, lon)
# for _, row in stops_df.iterrows():
#     key = row['normalized']
#     if key and key not in gtfs_lookup:
#         gtfs_lookup[key] = (row['stop_name'], row['stop_lat'], row['stop_lon'])

# # Special station lookup - check for both STATION and TERMINAL
# station_lookup = {}
# for _, row in stops_df.iterrows():
#     # Check for STATION or TERMINAL in stop_name
#     if any(x in row["stop_name"].upper() for x in ["STATION", "TERMINAL"]):
#         clean_name = clean_station(row["normalized"])
#         station_lookup[clean_name] = (
#             row["stop_name"],
#             row["stop_lat"],
#             row["stop_lon"]
#         )

# canonical_gtfs_lookup = defaultdict(list)
# for _, row in stops_df.iterrows():
#     c = canonical_intersection(row["normalized"])
#     if c:
#         canonical_gtfs_lookup[c].append(
#             (
#                 row["stop_name"],
#                 row["stop_lat"],
#                 row["stop_lon"]
#             )
#         )

# gtfs_keys = list(gtfs_lookup.keys())
# print(f"Unique GTFS normalized keys: {len(gtfs_keys)}")
# print(f"Station lookup keys: {len(station_lookup)}")

# # Blocking dictionary
# blocked = defaultdict(list)
# for key in gtfs_keys:
#     block = key[:1] if len(key) >= 2 else key
#     blocked[block].append(key)

# # Build route->stops mapping for ONLY the routes present in bus data
# trip_route = dict(zip(trips_df['trip_id'], trips_df['route_id']))

# stop_info = {}
# for _, row in stops_df.iterrows():
#     stop_info[row['stop_id']] = (row['stop_name'], row['normalized'])

# route_stops = defaultdict(set)
# for _, row in stop_times_df.iterrows():
#     trip_id = row['trip_id']
#     stop_id = row['stop_id']
#     route_id = trip_route.get(trip_id)
#     if route_id and str(route_id) in valid_route_ids and stop_id in stop_info:
#         _, norm_stop = stop_info[stop_id]
#         route_stops[str(route_id)].add(norm_stop)

# # Convert route_stops sets to lists for faster iteration
# route_stops = {k: list(v) for k, v in route_stops.items()}
# print(f"Built route->stops mapping for {len(route_stops)} routes (filtered to {len(valid_route_ids)} bus routes)")

# # Helper functions
# GEOCODE_FALLBACK = True

# def exact_match(norm_key):
#     return gtfs_lookup.get(norm_key, None)

# # Cache for route-restricted fuzzy matches
# fuzzy_cache = {}

# def fuzzy_match(norm_key, route_ids=None, score_cutoff=75):
#     cache_key = (norm_key, tuple(sorted(route_ids)) if route_ids else None)
#     if cache_key in fuzzy_cache:
#         return fuzzy_cache[cache_key]

#     if route_ids:
#         candidates = []
#         for rid in route_ids:
#             candidates.extend(route_stops.get(str(rid), []))
#         candidates = list(set(candidates))
#     else:
#         candidates = gtfs_keys

#     if not candidates:
#         return None, None, None, None, 0

#     # create cleaned lookup
#     cleaned_candidates = {}
#     for x in candidates:
#         cleaned = clean_station(x)
#         if cleaned not in cleaned_candidates:
#             cleaned_candidates[cleaned] = x

#     result = process.extractOne(clean_station(norm_key), list(cleaned_candidates.keys()), scorer=fuzz.WRatio)

#     if result:
#         cleaned_best, score = result
#         original_key = cleaned_candidates[cleaned_best]
#         stop_name, lat, lon = gtfs_lookup[original_key]

#         if score >= score_cutoff:
#             fuzzy_cache[cache_key] = (
#                 stop_name,
#                 lat,
#                 lon,
#                 original_key,
#                 score
#             )
#             return (
#                 stop_name,
#                 lat,
#                 lon,
#                 original_key,
#                 score
#             )

#     return None, None, None, None, 0

# # Cache for full fuzzy - SAFE version with moderate threshold
# full_fuzzy_cache = {}

# def full_fuzzy_match(norm_key, score_cutoff=85):
#     cache_key = (norm_key, score_cutoff)
#     if cache_key in full_fuzzy_cache:
#         return full_fuzzy_cache[cache_key]

#     block = norm_key[:2] if len(norm_key) >= 2 else norm_key
#     candidates = blocked.get(block, gtfs_keys)

#     if not candidates:
#         full_fuzzy_cache[cache_key] = (None, None, None, None, 0)
#         return None, None, None, None, 0

#     cleaned_map = {}
#     for x in candidates:
#         cleaned = clean_station(x)
#         if cleaned:
#             cleaned_map[cleaned] = x

#     result = process.extractOne(
#         clean_station(norm_key),
#         list(cleaned_map.keys()),
#         scorer=fuzz.WRatio
#     )

#     if result:
#         cleaned_best, score = result
#         original_key = cleaned_map[cleaned_best]

#         if original_key in gtfs_lookup:
#             stop_name, lat, lon = gtfs_lookup[original_key]

#             if score >= score_cutoff:
#                 full_fuzzy_cache[cache_key] = (
#                     stop_name,
#                     lat,
#                     lon,
#                     original_key,
#                     score
#                 )
#                 return (
#                     stop_name,
#                     lat,
#                     lon,
#                     original_key,
#                     score
#                 )

#     full_fuzzy_cache[cache_key] = (None, None, None, None, 0)
#     return None, None, None, None, 0

# def is_address_like(text):
#     return bool(re.search(r'\d', text)) and len(text.split()) >= 2

# geolocator = Nominatim(user_agent="ttc_location_updater")
# geocode_cache = {}

# def geocode_address(address):
#     if address in geocode_cache:
#         return geocode_cache[address]
#     try:
#         time.sleep(1)
#         loc = geolocator.geocode(f"{address}, Toronto, ON", timeout=10)
#         if loc is not None:
#             lat, lon = loc.latitude, loc.longitude
#             if math.isfinite(lat) and math.isfinite(lon):
#                 geocode_cache[address] = (lat, lon)
#                 return lat, lon
#     except Exception:
#         pass
#     geocode_cache[address] = (None, None)
#     return None, None

# def find_nearest_stop(lat, lon):
#     if lat is None or lon is None or not (math.isfinite(lat) and math.isfinite(lon)):
#         return None, None, None, None
#     min_dist = float('inf')
#     best = None
#     for _, row in stops_df.iterrows():
#         s_lat, s_lon = row['stop_lat'], row['stop_lon']
#         if not (math.isfinite(s_lat) and math.isfinite(s_lon)):
#             continue
#         d = geodesic((lat, lon), (s_lat, s_lon)).meters
#         if d < min_dist:
#             min_dist = d
#             best = row
#     if best is not None:
#         return best['stop_name'], best['stop_lat'], best['stop_lon'], min_dist
#     return None, None, None, None

# def validate_route_match(stop_name, routes):
#     """Validate that a stop belongs to the given routes using normalized names"""
#     if not routes:
#         return True
    
#     # Normalize the stop name for comparison
#     stop_norm = normalize_location_combined(stop_name)
    
#     # Get all stop names for the given routes
#     route_candidates = []
#     for r in routes:
#         route_candidates.extend(route_stops.get(str(r), []))
    
#     # Normalize all candidate stop names
#     route_candidates_norm = [
#         normalize_location_combined(x)
#         for x in route_candidates
#     ]
    
#     return stop_norm in route_candidates_norm

# # Process each unique location
# results = []
# unmatched_ids = []
# geocode_attempts = 0

# for idx, row in tqdm(unique_df.iterrows(), total=len(unique_df), desc="Matching locations"):
#     loc_id = row['location_id']
#     raw = row['location']
#     norm_key = normalize_location_combined(raw)
#     routes = row['routes_list']
#     best_norm = norm_key
#     best_stop_name = None
#     best_lat = None
#     best_lon = None
#     match_type = "unmatched"

#     # Check if this is a station
#     station_words = ["STATION", "SUBWAY", "TERMINAL", "LOOP"]
#     is_station = any(x in raw.upper() for x in station_words)

#     # ---- Tier 1: Station exact match ----
#     if is_station:
#         clean_key = clean_station(norm_key)
#         if clean_key in station_lookup:
#             stop_name, lat, lon = station_lookup[clean_key]
#             best_stop_name = stop_name
#             best_lat = lat
#             best_lon = lon
#             match_type = "station_exact"
#             results.append({
#                 'location_id': loc_id,
#                 'gtfs_stop_name': best_stop_name,
#                 'stop_lat': best_lat,
#                 'stop_lon': best_lon,
#                 'match_type': match_type
#             })
#             continue

#     # ---- Tier 2: Exact match ----
#     match = exact_match(norm_key)
#     if match:
#         stop_name, lat, lon = match
#         best_norm = stop_name
#         best_stop_name = stop_name
#         best_lat = lat
#         best_lon = lon
#         match_type = "exact"
#         results.append({
#             'location_id': loc_id,
#             'gtfs_stop_name': best_stop_name,
#             'stop_lat': best_lat,
#             'stop_lon': best_lon,
#             'match_type': match_type
#         })
#         continue

#     # ---- Tier 3: Canonical intersection ----
#     canonical = canonical_intersection(norm_key)
#     if canonical and canonical in canonical_gtfs_lookup:
#         candidates = canonical_gtfs_lookup[canonical]
#         chosen = None
#         for candidate in candidates:
#             if validate_route_match(candidate[0], routes):
#                 chosen = candidate
#                 break
#         if chosen:
#             stop_name, lat, lon = chosen
#         else:
#             stop_name, lat, lon = candidates[0]

#         best_norm = stop_name
#         best_stop_name = stop_name
#         best_lat = lat
#         best_lon = lon
#         match_type = "intersection_exact"

#         results.append({
#             'location_id': loc_id,
#             'gtfs_stop_name': best_stop_name,
#             'stop_lat': best_lat,
#             'stop_lon': best_lon,
#             'match_type': match_type
#         })
#         continue

#     # ---- Tier 4: Route-restricted fuzzy ----
#     # Higher cutoff for stations to avoid false matches
#     cutoff = 85 if is_station else 80
    
#     stop_name, lat, lon, matched_key, score = fuzzy_match(
#         norm_key,
#         route_ids=routes,
#         score_cutoff=cutoff
#     )
    
#     # If station and first cutoff failed, try with lower threshold
#     if is_station and not stop_name:
#         stop_name, lat, lon, matched_key, score = fuzzy_match(
#             norm_key,
#             route_ids=routes,
#             score_cutoff=70
#         )
    
#     # If not station, try with 85 if first failed
#     if not is_station and not stop_name:
#         stop_name, lat, lon, matched_key, score = fuzzy_match(
#             norm_key,
#             route_ids=routes,
#             score_cutoff=85
#         )

#     if stop_name and validate_route_match(stop_name, routes):
#         best_norm = stop_name
#         best_stop_name = stop_name
#         best_lat = lat
#         best_lon = lon
#         match_type = f"fuzzy_{score}"
#         results.append({
#             'location_id': loc_id,
#             'gtfs_stop_name': best_stop_name,
#             'stop_lat': best_lat,
#             'stop_lon': best_lon,
#             'match_type': match_type
#         })
#         continue

#     # ---- Tier 5: Global fuzzy fallback (controlled) ----
#     stop_name, lat, lon, matched_key, score = full_fuzzy_match(
#         norm_key,
#         score_cutoff=75  # Lowered from 88 to catch more matches
#     )

#     if stop_name:
#         # validate route if possible
#         route_ok = validate_route_match(stop_name, routes)
#         if route_ok:
#             best_stop_name = stop_name
#             best_lat = lat
#             best_lon = lon
#             match_type = f"global_fuzzy_{score}"
#             results.append({
#                 'location_id': loc_id,
#                 'gtfs_stop_name': best_stop_name,
#                 'stop_lat': best_lat,
#                 'stop_lon': best_lon,
#                 'match_type': match_type
#             })
#             continue

#     # ---- Tier 6: Geocoding (with distance filter) ----
#     if GEOCODE_FALLBACK and (is_address_like(raw) or is_address_like(norm_key)):
#         addr = raw if is_address_like(raw) else norm_key
#         lat, lon = geocode_address(addr)
#         geocode_attempts += 1
#         if lat is not None and lon is not None and math.isfinite(lat) and math.isfinite(lon):
#             stop_name, s_lat, s_lon, dist = find_nearest_stop(lat, lon)
#             # Only accept stops within 250 meters
#             if stop_name and dist and dist <= 250:
#                 best_norm = stop_name
#                 best_stop_name = stop_name
#                 best_lat = s_lat
#                 best_lon = s_lon
#                 match_type = f"geo_{dist:.0f}m"
#                 results.append({
#                     'location_id': loc_id,
#                     'gtfs_stop_name': best_stop_name,
#                     'stop_lat': best_lat,
#                     'stop_lon': best_lon,
#                     'match_type': match_type
#                 })
#                 continue

#     # ---- Tier 7: Unmatched ----
#     unmatched_ids.append(loc_id)
#     results.append({
#         'location_id': loc_id,
#         'gtfs_stop_name': best_stop_name,
#         'stop_lat': best_lat,
#         'stop_lon': best_lon,
#         'match_type': match_type
#     })

# print(f"Geocoding attempted for {geocode_attempts} locations (if enabled)")

# # Merge and save
# update_df = pd.DataFrame(results)
# updated_unique = (unique_df[['location', 'location_id']].merge(update_df, on='location_id', how='left'))
# # remove duplicate IDs if any
# updated_unique = (updated_unique.drop_duplicates(subset=['location_id']))

# updated_unique.to_csv(OUTPUT_DIR / "unique_locations_lookup1.csv", index=False)

# print(f"\nUpdated unique locations saved to {OUTPUT_DIR / 'unique_locations_lookup1.csv'}")
# print(f"Total locations: {len(updated_unique)}")
# print(f"Matched: {len(update_df[update_df['match_type'] != 'unmatched'])}")
# print(f"Unmatched: {len(update_df[update_df['match_type'] == 'unmatched'])}")

# # Print match type breakdown
# print("\nMatch type breakdown:")
# print(update_df['match_type'].value_counts())

# # Create unmatched review file
# unmatched_df = updated_unique[updated_unique["match_type"] == "unmatched"]
# if len(unmatched_df) > 0:
#     unmatched_df.to_csv(OUTPUT_DIR / "unmatched_locations_review.csv", index=False)
#     print(f"\nUnmatched locations saved to {OUTPUT_DIR / 'unmatched_locations_review.csv'}")
#     print(f"Total unmatched: {len(unmatched_df)}")

# %%
# # SECOND PASS MATCHING ONLY UNMATCHED LOCATIONS
# # Street Pair Exact -> Fuzzy WRatio -> Save lookup2
# DATA_DIR = Path("data")
# RAW_DIR = DATA_DIR / "raw"
# OUTPUT_DIR = Path("output")
# GTFS_DIR = RAW_DIR / "ttc_gtfs"

# route_location_lookup = pd.read_csv(OUTPUT_DIR / "route_location_lookup.csv")
# unique_df = pd.read_csv(OUTPUT_DIR / "unique_locations_lookup1.csv")
# stops_df = pd.read_csv(GTFS_DIR / "stops.txt")

# stops_df = stops_df.dropna(subset=["stop_lat", "stop_lon"])
# print("Total locations:", len(unique_df))

# routes_per_location = (route_location_lookup.groupby("location_id")["route"].apply(lambda x: list(set(x.astype(str)))).to_dict())

# valid_location_ids = set(route_location_lookup["location_id"])
# unique_df = unique_df[unique_df["location_id"].isin(valid_location_ids)].copy()
# unique_df["routes_list"] = (unique_df["location_id"].map(routes_per_location))

# unique_df["routes_list"] = (
#     unique_df["routes_list"]
#     .apply(lambda x: x if isinstance(x,list) else [])
# )
# print("Locations after filtering:", len(unique_df))


# # Get only unmatched
# unmatched_df = unique_df[unique_df["match_type"]=="unmatched"].copy()
# print("Unmatched before second pass:", len(unmatched_df))

# # Normalization
# COMMON_FIXES = {
#     "TRITION":"TRITON",
#     "BOROUGHQ":"BOROUGH",
#     "BOROUG":"BOROUGH",
#     "BOUROUGH":"BOROUGH",
#     "KNIFGHTSB":"KNIGHTSBRIDGE",
#     "KNIGHTSBR":"KNIGHTSBRIDGE",
#     "EDLIOU":"EDILOU",
#     "HRONER":"HORNER",
#     "MCNICOL":"MCNICOLL",
#     "NAIRIN":"NAIRN",
#     "ABOT":"ABBOT"
# }

# def normalize_location_combined(text):
#     if not isinstance(text,str):
#         return ""

#     text=text.upper().strip()
#     for old,new in COMMON_FIXES.items():
#         text=text.replace(old,new)
        
#     text=re.sub(r"\bAND\b","&", text)
#     text=re.sub(r"\bAT\b","&", text)
#     text=re.sub(r"\s+"," ",text)
#     return text.strip()

# # Street pair extraction
# def street_pair(text):
#     text=normalize_location_combined(text)
#     if "&" not in text:
#         return None

#     parts=text.split("&")
#     if len(parts)!=2:
#         return None
        
#     streets=[]
#     for p in parts:
#         p=re.sub(
#             r"\b(ST|STREET|RD|ROAD|AVE|AV|AVENUE|DR|DRIVE|BLVD|BOULEVARD|HWY)\b",
#             "",
#             p
#         )
#         p=p.strip()
        
#         if p:
#             streets.append(p)

#     if len(streets)==2:

#         return "|".join(
#             sorted(streets)
#         )
#     return None

# # Normalize GTFS
# print("Normalizing GTFS")
# tqdm.pandas(desc="GTFS normalization")

# stops_df["normalized"] = (stops_df["stop_name"].progress_apply(normalize_location_combined))

# # Build GTFS lookup
# gtfs_lookup={}
# for _,row in stops_df.iterrows():
#     key=row["normalized"]
#     if key not in gtfs_lookup:
#         gtfs_lookup[key]=(
#             row["stop_name"],
#             row["stop_lat"],
#             row["stop_lon"]
#         )

# gtfs_keys=list(gtfs_lookup.keys())
# print("GTFS keys:",len(gtfs_keys))

# # Build street pair lookup
# print("Building street pair lookup")

# street_lookup={}
# for _,row in stops_df.iterrows():
#     key=street_pair(row["stop_name"])

#     if key:
#         street_lookup[key]=(
#             row["stop_name"],
#             row["stop_lat"],
#             row["stop_lon"]
#         )
        
# print("Street pair keys:", len(street_lookup))

# # Process unmatched
# results=[]
# for _,row in tqdm(
#     unmatched_df.iterrows(),
#     total=len(unmatched_df),
#     desc="Second pass matching"
# ):

#     loc_id = row["location_id"]
#     original = row["location"]
#     routes = row["routes_list"]

#     result = {
#         "location_id": loc_id,
#         "normalized_best": original,
#         "gtfs_stop_name": None,
#         "stop_lat": None,
#         "stop_lon": None,
#         "match_type": "unmatched"
#     }

#     # Tier 1: Street pair exact
#     pair=street_pair(original)
#     if pair in street_lookup:
#         stop,lat,lon = street_lookup[pair]
#         result.update({
#             "normalized_best":stop,
#             "gtfs_stop_name":stop,
#             "stop_lat":lat,
#             "stop_lon":lon,
#             "match_type":"street_pair_exact"
#         })

#         results.append(result)
#         continue

#     # Tier 2: Fuzzy WRatio
#     norm=normalize_location_combined(original)
#     # Route restricted candidates
#     candidates=[]
    
#     for rid in routes:
#         candidates.extend(route_stops.get(str(rid), []))
    
#     candidates=list(set(candidates))
    
#     if not candidates:
#         candidates=gtfs_keys
    
#     fuzzy_result=process.extractOne(
#         norm,
#         candidates,
#         scorer=fuzz.WRatio
#     )
#     if fuzzy_result:
#         best_key,score,_=fuzzy_result
#         # threshold
#         if score >= 75:
#             stop,lat,lon = gtfs_lookup[best_key]
#             result.update({
#                 "normalized_best":stop,
#                 "gtfs_stop_name":stop,
#                 "stop_lat":lat,
#                 "stop_lon":lon,
#                 "match_type":
#                     f"second_fuzzy_{score}"
#             })

#     results.append(result)

# # Create second pass dataframe
# second_df=pd.DataFrame(results)
# print(
#     "\nSecond pass matched:",
#     len(
#         second_df[
#             second_df["match_type"]!="unmatched"
#         ]
#     )
# )

# # Merge back
# updated = unique_df.merge(
#     second_df,
#     on="location_id",
#     how="left",
#     suffixes=("","_new")
# )

# for col in [
#     "normalized_best",
#     "gtfs_stop_name",
#     "stop_lat",
#     "stop_lon",
#     "match_type"
# ]:
    
#     new_col=col+"_new"
#     if new_col in updated.columns:
#         updated[col]=(
#             updated[new_col]
#             .combine_first(
#                 updated[col]
#             )
#         )

#         updated.drop(
#             columns=[new_col],
#             inplace=True
#         )

# updated.drop(
#     columns=[
#         "normalized_best"
#     ],
#     inplace=True,
#     errors="ignore"
# )

# # Save
# output_file = (OUTPUT_DIR /"unique_locations_lookup2.csv")
# updated.to_csv(output_file, index=False)
# print("\nSaved:")
# print(output_file)
# print("\nFinal results:")
# print(updated["match_type"].value_counts())
